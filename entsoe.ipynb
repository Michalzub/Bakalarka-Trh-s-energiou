# %%
from entsoe import EntsoePandasClient
import pandas as pd

client = EntsoePandasClient(api_key="ce2a6208-fcc4-46d7-991b-f0313dc9ba38")
start = pd.Timestamp('20251001', tz='Europe/Bratislava')
end = pd.Timestamp('20251201', tz='Europe/Bratislava')
country_code = 'DE_LU'

client.query_wind_and_solar_forecast(country_code, start=start, end=end, psr_type=None)
# Out:
#                            Solar  Wind Offshore  Wind Onshore
# 2025-10-01 00:00:00+02:00    0.0        1799.64    7509.74000
# 2025-10-01 00:15:00+02:00    0.0        1801.96    7318.31000
# 2025-10-01 00:30:00+02:00    0.0        1800.30    7131.36000
# 2025-10-01 00:45:00+02:00    0.0        1794.83    6954.46000
# 2025-10-01 01:00:00+02:00    0.0        1792.16    6775.58000
# ...                          ...            ...           ...
# 2025-11-30 22:45:00+01:00    0.0        5058.29   16680.13701
# 2025-11-30 23:00:00+01:00    0.0        5007.39   16417.66405
# 2025-11-30 23:15:00+01:00    0.0        4955.77   16183.06267
# 2025-11-30 23:30:00+01:00    0.0        4914.29   15949.42328
# 2025-11-30 23:45:00+01:00    0.0        4848.83   15721.07088
#
# [5860 rows x 3 columns]
